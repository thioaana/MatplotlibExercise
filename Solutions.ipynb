# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1: Read Total profit of all months and show it using a line plot<br>
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# X label name = Month Number<br>
# Y label name = Total profit

# %%
df = pd.read_csv("company_sales_data.csv")

# %%
x = df["month_number"]
y = df["total_profit"]
fig, ax = plt.subplots()
ax.plot(x, y)

ax.set_xlabel("Month")
ax.set_ylabel("Total Profit")
ax.set_title("Total profit per month")
plt.xticks(ticks=x)
plt.yticks(np.linspace(100000, 500000, 5))
# Out:
# ([<matplotlib.axis.YTick at 0x7f68d91f2dd0>,
#   <matplotlib.axis.YTick at 0x7f68d9293510>,
#   <matplotlib.axis.YTick at 0x7f68d9e65c10>,
#   <matplotlib.axis.YTick at 0x7f68d89c1450>,
#   <matplotlib.axis.YTick at 0x7f68d89c1990>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Exercise 2: Get total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red<br>
# Show legend at the lower right location.<br>
# X label name = Month Number<br>
# Y label name = Sold units number<br>
# Add a circle marker.<br>
# Line marker color as read<br>
# Line width should be 3<br>

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color="red", linestyle="--", label="Profit data of last year",
        marker="o", markerfacecolor="black", linewidth=3)

ax.set_xlabel("Month Number")
ax.set_ylabel("Sales Units")
ax.set_title("Sales data")
# ax.legend(loc = "lower right")
plt.xticks(ticks=x)
plt.yticks(np.linspace(100000, 500000, 5))
# Out:
# ([<matplotlib.axis.YTick at 0x7f68d8723510>,
#   <matplotlib.axis.YTick at 0x7f68d871da90>,
#   <matplotlib.axis.YTick at 0x7f68d8718e50>,
#   <matplotlib.axis.YTick at 0x7f68d86e5710>,
#   <matplotlib.axis.YTick at 0x7f68d86e5c50>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
fig, ax = plt.subplots()
ax.plot(x, df["facecream"], label="Face cream", marker="o", linewidth=3)
ax.plot(x, df["facewash"], label="Face wash", marker="o", linewidth=3)
ax.plot(x, df["toothpaste"], label="Toothpaste", marker="o", linewidth=3)
ax.plot(x, df["bathingsoap"], label="Bathing soap", marker="o", linewidth=3)
ax.plot(x, df["shampoo"], label="Shampoo", marker="o", linewidth=3)
ax.plot(x, df["moisturizer"], label="Moisturizer", marker="o", linewidth=3)

ax.set_xlabel("Month Number")
ax.set_ylabel("Units sold")
ax.set_title("Sales data")
ax.legend(loc = "upper left")
plt.xticks(ticks=x)
plt.yticks([1000, 2000, 4000, 6000, 10000, 12000, 15000, 18000])
# Out:
# ([<matplotlib.axis.YTick at 0x7f68d876d710>,
#   <matplotlib.axis.YTick at 0x7f68da0c1f90>,
#   <matplotlib.axis.YTick at 0x7f68d8682410>,
#   <matplotlib.axis.YTick at 0x7f68d8972990>,
#   <matplotlib.axis.YTick at 0x7f68d86a8410>,
#   <matplotlib.axis.YTick at 0x7f68d86a87d0>,
#   <matplotlib.axis.YTick at 0x7f68d86a8e10>,
#   <matplotlib.axis.YTick at 0x7f68d86b3390>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, df["toothpaste"], label="Toothpaste")

ax.set_xlabel("Month Number")
ax.set_ylabel("Units sold")
ax.set_title("Sales data")
ax.legend(loc = "upper left")
plt.grid(which="major", linestyle="--", linewidth=1)
plt.xticks(ticks=x)
# Out:
# ([<matplotlib.axis.XTick at 0x7f68d8671150>,
#   <matplotlib.axis.XTick at 0x7f68d8671e90>,
#   <matplotlib.axis.XTick at 0x7f68d8671a50>,
#   <matplotlib.axis.XTick at 0x7f68d862d850>,
#   <matplotlib.axis.XTick at 0x7f68d862dd90>,
#   <matplotlib.axis.XTick at 0x7f68d8638350>,
#   <matplotlib.axis.XTick at 0x7f68d8638890>,
#   <matplotlib.axis.XTick at 0x7f68d8638dd0>,
#   <matplotlib.axis.XTick at 0x7f68d85c0350>,
#   <matplotlib.axis.XTick at 0x7f68d85c0750>,
#   <matplotlib.axis.XTick at 0x7f68d862da10>,
#   <matplotlib.axis.XTick at 0x7f68d85c0710>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.bar([a-0.25 for a in x], df["facecream"], label="Face cream", width=0.25, align="edge")
ax.bar([a for a in x], df["facewash"], label="Face wash", width=0.25, align="edge")

ax.set_xlabel("Month Number")
ax.set_ylabel("Units sold")
ax.set_title("Sales data")
ax.legend(loc = "upper left")
plt.grid(which="major", linestyle="--", linewidth=1)
plt.xticks(ticks=x)
# Out:
# ([<matplotlib.axis.XTick at 0x7f68d858eb90>,
#   <matplotlib.axis.XTick at 0x7f68d85938d0>,
#   <matplotlib.axis.XTick at 0x7f68d85934d0>,
#   <matplotlib.axis.XTick at 0x7f68d8516590>,
#   <matplotlib.axis.XTick at 0x7f68d8516ad0>,
#   <matplotlib.axis.XTick at 0x7f68d8516f90>,
#   <matplotlib.axis.XTick at 0x7f68d851e5d0>,
#   <matplotlib.axis.XTick at 0x7f68d851eb10>,
#   <matplotlib.axis.XTick at 0x7f68d851efd0>,
#   <matplotlib.axis.XTick at 0x7f68d851ea50>,
#   <matplotlib.axis.XTick at 0x7f68d851eb90>,
#   <matplotlib.axis.XTick at 0x7f68d8524710>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(x, df["bathingsoap"], color="red", marker="o", linewidth=3)
ax[1].plot(x, df["facewash"], color="black", marker="o", linewidth=3)

ax[0].set_title("Sales data of Facewash")
ax[1].set_title("Sales data of Bathingsoap")

plt.xlabel("Moths")
plt.ylabel("Units sold")
# Out:
# Text(0, 0.5, 'Units sold')

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(x, df["bathingsoap"], color="red", marker="o", linewidth=3)
ax[1].plot(x, df["facewash"], color="black", marker="o", linewidth=3)

ax[0].set_title("Sales data of Facewash")
ax[1].set_title("Sales data of Bathingsoap")

plt.xlabel("Moths")
plt.ylabel("Units sold")

plt.show()

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200
